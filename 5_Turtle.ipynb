# %% [markdown]
# <a href="https://colab.research.google.com/github/pinedodaniel/upf/blob/main/5_Turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inteligencia Artificial y sus aplicaciones
# ### Turtle graphics

# %% [markdown]
# ### Codigo de ejemplo:

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=fab65a746bd86519ce63b11df2ccca77b21052dac73c63eeb839b91e0f395dc0
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
initializeTurtle()
speed(13)
for i in range(0,4):
  forward(100)
  right(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="150.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
#Other Commands
#pensize(5)
#turtle.pendown()
#turtle.penup()
#pencolor("red")
#pencolor(255, 0, 0)
#speed(10)

# %% [markdown]
# # Challenges:

# %% [markdown]
# *Challenge 1:* Dibuja un triangulo equilatero (todos los angulos deben de ser iguales)

# %% [markdown]
# *Challenge 2:* Utlizando solo cuadrados, dibuja una figura que sea semejante a este patrón:
#
#
#
#
#
# ![Screenshot 2021-07-01 at 1.56.19 AM.png](data:image/png;base64,...)

# %%
initializeTurtle()
speed(11)
for i in range (0,12):
  for j in range(0,4):
    forward(100)
    right(90)
  right(360/12)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# *Challenge 3:* Dibuje una estrella de 5 puntas:

# %% [markdown]
# *Challenge 4:* Crea la siguiente figura:
#
# ![Screenshot 2021-07-01 at 1.47.21 AM.png](data:image/png;base64,...)

# %% [markdown]
# Challenge 5: Crea la siguiente figura:
# ![Screen Shot 2022-06-28 at 13.34.39.png](data:image/png;base64,...)

# %% [markdown]
# Challenge 6: Inspirado por los anteriores challenges, inventa una figura geométrica interesante (introduce colores si quieres)
