# %% [markdown]
# # Inteligencia Artificial y sus aplicaciones
#
# ### Turtle graphics - *EJERCICIOS  EXTRA AVANZADOS*
# -----

# %%
#Other Commands
#pensize(5)
#turtle.pendown()
#turtle.penup()
#pencolor("red")
#pencolor(255, 0, 0)
#speed(10)

# %% [markdown]
# Recordar que debéis importar:

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

# %% [markdown]
# ----
# *Challenge 7*: Crea la siguiente figura:

# %% [markdown]
# ![Screenshot 2023-07-05 at 12.39.38 AM.png](data:image/png;base64,...)

# %% [markdown]
# ----
# *Challenge 8:* Dibuja dos estrellas de 50 puntas:

# %% [markdown]
# ![Screenshot 2023-07-05 at 12.39.49 AM.png](data:image/png;base64,...)

# %% [markdown]
# ----
# *Challenge 9:* Dibuja la siguiente figura:

# %% [markdown]
# ![Screenshot 2023-07-05 at 12.39.56 AM.png](data:image/png;base64,...)

# %% [markdown]
# ----
# *Challenge 10:* Dibuja la siguiente figura:
#
# ![Screenshot 2023-07-06 at 11.51.52 AM.png](data:image/png;base64,...)

# %% [markdown]
# *Challenge 11:* Dibuja la siguiente figura:![Screenshot 2023-07-06 at 12.26.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# -----
# *Challenge 12:* Dibuja la siguiente figura:

# %% [markdown]
# ![Screenshot 2023-07-06 at 12.31.58 PM.png](data:image/png;base64,...)

# %% [markdown]
# -----
# *Challenge 13:* Dibuja la siguiente figura:

# %% [markdown]
# ![Screenshot 2023-07-05 at 12.10.06 AM.png](data:image/png;base64,...)

# %% [markdown]
# ----
# *Challenge 14:* Usa el codigo del Challenge 13 para dibujar la siguiente figura:

# %% [markdown]
# ![Screenshot 2023-07-06 at 11.51.35 AM.png](data:image/png;base64,...)
